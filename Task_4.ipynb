# %% [markdown]
# <a href="https://colab.research.google.com/github/Devphadatare/Prodigy-Infotech/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.

# %% [markdown]
# #1: Import Libraries and Load Data

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Load the dataset
file_path = 'twitter_training.csv'
df = pd.read_csv(file_path)

# Rename columns for ease of use
df.columns = ['ID', 'Topic', 'Sentiment', 'Tweet']

# %% [markdown]
# #2: Sentiment Counts and Data Overview

# %%
# Display sentiment counts
sentiment_counts = df['Sentiment'].value_counts()

# Print sentiment counts to understand distribution
print(sentiment_counts)
# Out:
# Sentiment
# Negative      22542
# Positive      20831
# Neutral       18318
# Irrelevant    12990
# Name: count, dtype: int64

# %% [markdown]
# #3: Bar Plot for Sentiment Distribution

# %%
# Plot 1: Bar Plot for Sentiment Distribution
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sentiment', palette='Set2')
plt.title('Sentiment Distribution in Social Media Data', fontsize=16)
plt.xlabel('Sentiment', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-652a10a533ba>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Sentiment', palette='Set2')

# %% [markdown]
# #4: Pie Chart for Sentiment Proportions

# %%
# Plot 2: Pie Chart for Sentiment Proportions
plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title('Sentiment Proportions in Social Media Data', fontsize=16)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# #5: Word Clouds and Simulated Time-based Analysis

# %%
# Plot 3: Word Clouds for each sentiment
for sentiment in sentiment_counts.index:
    plt.figure(figsize=(8, 6))
    text = ' '.join(df[df['Sentiment'] == sentiment]['Tweet'].dropna())
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'Word Cloud for {sentiment} Tweets', fontsize=16)
    plt.show()

# Optional Plot 4: Bar Plot simulating time-like sentiment distribution
df['Index'] = df.index  # Adding an 'Index' column to simulate time-like patterns

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Index', y='Sentiment', hue='Sentiment', palette='Set2')
plt.title('Sentiment Distribution by Index (Simulated)', fontsize=16)
plt.xlabel('Index (Simulated Time)', fontsize=12)
plt.ylabel('Sentiment', fontsize=12)
plt.xticks(rotation=45)
plt.show()
